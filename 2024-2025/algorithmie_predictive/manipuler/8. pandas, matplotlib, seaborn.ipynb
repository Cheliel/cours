# %% [markdown]
# # Pandas, Matplotlib, Seaborn

# %% [markdown]
# ## Installation de Pandas :
# * Installation de la bibliothèque : pip install pandas
# * Installation de la bibliothèque pyarrow : pip install pyarrow
# * Ajouter pandas à un projet : import pandas as pd
# * Documentation : https://pandas.pydata.org/
# * Tester l'import

# %%
import pandas as pd

# %% [markdown]
# ## Ouverture d'un fichier CSV

# %%
filename = "Automobile.csv"
donnes = pd.read_csv(filename, sep=',')

# %% [markdown]
# ## Informations sur les données
# * Dimensions des données
# * Liste des colonnes
# * Premières lignes
# * Premières statistiques sur les données

# %%
donnes.get('mpg')
donnes.head(60) # les 60 première ligne
#donnes.tail(20) # les 20 dernière ligne
#donnes.shape()
#donnes.columns()
donnes.describe()
# Out:
#               mpg   cylinders  displacement  horsepower       weight  \
# count  392.000000  392.000000    392.000000  392.000000   392.000000
# mean    23.445918    5.471939    194.411990  104.469388  2977.584184
# std      7.805007    1.705783    104.644004   38.491160   849.402560
# min      9.000000    3.000000     68.000000   46.000000  1613.000000
# 25%     17.000000    4.000000    105.000000   75.000000  2225.250000
# 50%     22.750000    4.000000    151.000000   93.500000  2803.500000
# 75%     29.000000    8.000000    275.750000  126.000000  3614.750000
# max     46.600000    8.000000    455.000000  230.000000  5140.000000
#
#        acceleration  model_year
# count    392.000000  392.000000
# mean      15.541327   75.979592
# std        2.758864    3.683737
# min        8.000000   70.000000
# 25%       13.775000   73.000000
# 50%       15.500000   76.000000
# 75%       17.025000   79.000000
# max       24.800000   82.000000

# %% [markdown]
# ## Accéder aux informations
# * Visualiser une colonne
# * Visualiser une ligne
# * Visualiser une sous matrice
# * Visualiser des lignes pour une colonne donnée

# %%
donnes['horsepower'] # get a column 
donnes[['horsepower', 'mpg']] # get columns 

donnes.iloc[1] # get specifique ligne 
donnes.loc[[4, 8, 11]] # get specifiques lignes
donnes['horsepower'][5:10] # get specifiques lign in column

donnes.iloc[5:13, 1:4] # get specific lignes and columns
donnes[['horsepower', 'mpg']][5:10] # get specific columns and lignes
# Out:
#    horsepower   mpg
# 5         198  15.0
# 6         220  14.0
# 7         215  14.0
# 8         225  14.0
# 9         190  15.0

# %% [markdown]
# ## Supprimer des lignes

# %%
donnes.drop([1, 2, 3], axis=0) # Axis 0 -> ligne // Axis 1 -> column
donnes.drop(['mpg', 'name'], axis=1)
donnes # you might want to assign result
# Out:
#                           name   mpg  cylinders  displacement  horsepower  \
# 0    chevrolet chevelle malibu  18.0          8         307.0         130
# 1            buick skylark 320  15.0          8         350.0         165
# 2           plymouth satellite  18.0          8         318.0         150
# 3                amc rebel sst  16.0          8         304.0         150
# 4                  ford torino  17.0          8         302.0         140
# ..                         ...   ...        ...           ...         ...
# 387            ford mustang gl  27.0          4         140.0          86
# 388                  vw pickup  44.0          4          97.0          52
# 389              dodge rampage  32.0          4         135.0          84
# 390                ford ranger  28.0          4         120.0          79
# 391                 chevy s-10  31.0          4         119.0          82
#
#      weight  acceleration  model_year  origin
# ...

# %% [markdown]
# ## Supprimer des colonnes

# %%
toDelet = donnes[donnes['origin'] == 'usa'].index
donnes.drop(toDelet)
# Out:
#                              name   mpg  cylinders  displacement  horsepower  \
# 14          toyota corona mark ii  24.0          4         113.0          95
# 18                   datsun pl510  27.0          4          97.0          88
# 19   volkswagen 1131 deluxe sedan  26.0          4          97.0          46
# 20                    peugeot 504  25.0          4         110.0          87
# 21                    audi 100 ls  24.0          4         107.0          90
# ..                            ...   ...        ...           ...         ...
# 377                   honda civic  38.0          4          91.0          67
# 378            honda civic (auto)  32.0          4          91.0          67
# 379                 datsun 310 gx  38.0          4          91.0          67
# 384              toyota celica gt  32.0          4         144.0          96
# 388                     vw pickup  44.0          4          97.0          52
#
# ...

# %% [markdown]
# ## Sélection des données
# * Sélectionner à partir d'un critère
# * Récupérer les index des lignes sélectionnées
# * Supprimer les lignes sélectionnées

# %%
mask = donnes['mpg'] > 30   # 
mask                        # get boolean value of witch ligne match the predicate
donnes[donnes['mpg'] > 30]  # apply predicate on donnes
donnes[mask]
# Out:
#                     name   mpg  cylinders  displacement  horsepower  weight  \
# 52   toyota corolla 1200  31.0          4          71.0          65    1773
# 53           datsun 1200  35.0          4          72.0          69    1613
# 127          datsun b210  31.0          4          79.0          67    1950
# 129  toyota corolla 1200  32.0          4          71.0          65    1836
# 142        toyota corona  31.0          4          76.0          52    1649
# ..                   ...   ...        ...           ...         ...     ...
# 384     toyota celica gt  32.0          4         144.0          96    2665
# 385    dodge charger 2.2  36.0          4         135.0          84    2370
# 388            vw pickup  44.0          4          97.0          52    2130
# 389        dodge rampage  32.0          4         135.0          84    2295
# 391           chevy s-10  31.0          4         119.0          82    2720
#
#      acceleration  model_year  origin
# ...

# %% [markdown]
# ## Quelques valeurs statistiques
# * Compter les valeurs
# * Moyenne avec aggrégation des données
# * Maximum/Minimum avec aggrégation des données

# %%
donnes['mpg'].value_counts()
donnes.groupby(['origin'])['mpg'].mean() # aggragate by origin -> get 'mpg' column -> get mean
donnes.groupby(['origin'])['mpg'].max()
donnes.groupby(['origin'])['mpg'].min()
donnes.groupby(['origin'])['mpg'].describe()['count'] # get a column of the result
donnes.groupby(['origin'])['mpg'].describe()

donnes[donnes['mpg'] == donnes['mpg'].min()] # the ligne with de minimal 'mpg' value
# donnes[donnes['mpg'] == 9.0] # equal
# Out:
#         name  mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28  hi 1200d  9.0          8         304.0         193    4732          18.5
#
#     model_year origin
# 28          70    usa

# %% [markdown]
# ## Installation de Matplotlib :
# * Installation de la bibliothèque : pip install matplotlib
# * Ajouter matplotlib à un projet : import matplotlib.pyplot as plt
# * Documentation : https://matplotlib.org/
# * Tester l'import

# %%
math = [13, 14, 12, 18, 5, 10, 14, 8, 13, 3]
prog = [14, 12, 15, 17, 7, 9, 16, 9, 13, 4]

# %% [markdown]
# # PANDA'S shit equal to plt.scatter(math, prog)

# %%
notes = pd.DataFrame({
    'notes math': math,
    'notes prog': prog
})
notes.plot(x='notes math', y='notes prog', kind='scatter')
# Out:
# <Axes: xlabel='notes math', ylabel='notes prog'>

# %%
import matplotlib.pyplot as plt 

math = [13, 14, 12, 18, 5, 10, 14, 8, 13, 3]
prog = [14, 12, 15, 17, 7, 9, 16, 9, 13, 4]

plt.scatter(math, prog)
plt.title('Correlation math-prog')
plt.xlabel('Note en math')
plt.ylabel('Note en prog')
plt.savefig('note.svg')

# %% [markdown]
# ## Installation de Seaborn :
# * Installation de la bibliothèque : pip install seaborn
# * Ajouter seaborn à un projet : import seaborn as sns
# * Documentation : https://seaborn.pydata.org/
# * Tester l'import

# %%
import seaborn as sns

# %% [markdown]
# ## Coefficiant de correlation avec Numpy

# %%
import numpy as np

math = [13, 14, 12, 18, 5, 10, 14, 8, 13, 3]
prog = [14, 12, 15, 17, 7, 9, 16, 9, 13, 4]

np.corrcoef(math, prog)
# Out:
# array([[1.        , 0.93789962],
#        [0.93789962, 1.        ]])
